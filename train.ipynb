# %%
import torch
from train import *
from dataset import build_dataloaders
from bilstm import BiLSTMAttentionClassifier

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BiLSTMAttentionClassifier(
    pc_vocab=9,
    acc_vocab=10,
    oct_vocab=7,
    dur_vocab=33,
    meas_vocab=4,
    emb_dim=32,
    lstm_hidden=128,
    num_classes=12,
    dropout=0.3
)
model.to(device)

train_loader, class_weights, val_loader, _ = build_dataloaders(
    "vocab.pkl", "dataset.pkl", batch_size=8)

criterion = torch.nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=3
)

# %%
train_model(model, train_loader, val_loader, optimizer, scheduler,
            criterion, device, num_epochs=50, patience=7)
# Out:
# Epoch 01 | Train Loss: 1.9009, Train Acc: 0.3428 | Val Loss: 1.0508, Val Acc: 0.6552
# Best model saved (val_loss=1.0508)
# Epoch 02 | Train Loss: 0.7753, Train Acc: 0.7396 | Val Loss: 0.4894, Val Acc: 0.8218
# Best model saved (val_loss=0.4894)
# Epoch 03 | Train Loss: 0.4171, Train Acc: 0.8600 | Val Loss: 0.3894, Val Acc: 0.8621
# Best model saved (val_loss=0.3894)
# Epoch 04 | Train Loss: 0.3055, Train Acc: 0.8907 | Val Loss: 0.3805, Val Acc: 0.8506
# Best model saved (val_loss=0.3805)
# Epoch 05 | Train Loss: 0.2810, Train Acc: 0.9152 | Val Loss: 0.2936, Val Acc: 0.8793
# Best model saved (val_loss=0.2936)
# Epoch 06 | Train Loss: 0.2037, Train Acc: 0.9337 | Val Loss: 0.2562, Val Acc: 0.8966
# Best model saved (val_loss=0.2562)
# Epoch 07 | Train Loss: 0.1919, Train Acc: 0.9373 | Val Loss: 0.2613, Val Acc: 0.8966
# No improvement (1/7)
# Epoch 08 | Train Loss: 0.1209, Train Acc: 0.9668 | Val Loss: 0.4173, Val Acc: 0.8736
# No improvement (2/7)
# Epoch 09 | Train Loss: 0.1265, Train Acc: 0.9644 | Val Loss: 0.2992, Val Acc: 0.8851
# No improvement (3/7)
# Epoch 10 | Train Loss: 0.1764, Train Acc: 0.9423 | Val Loss: 0.2170, Val Acc: 0.9253
# Best model saved (val_loss=0.2170)
# Epoch 11 | Train Loss: 0.1034, Train Acc: 0.9717 | Val Loss: 0.3215, Val Acc: 0.9253
# No improvement (1/7)
# Epoch 12 | Train Loss: 0.0928, Train Acc: 0.9681 | Val Loss: 0.3383, Val Acc: 0.8966
# No improvement (2/7)
# Epoch 13 | Train Loss: 0.0549, Train Acc: 0.9816 | Val Loss: 0.4829, Val Acc: 0.8908
# No improvement (3/7)
# Epoch 14 | Train Loss: 0.0736, Train Acc: 0.9754 | Val Loss: 0.2798, Val Acc: 0.9195
# No improvement (4/7)
# Epoch 15 | Train Loss: 0.0403, Train Acc: 0.9902 | Val Loss: 0.2039, Val Acc: 0.9195
# Best model saved (val_loss=0.2039)
# Epoch 16 | Train Loss: 0.0239, Train Acc: 0.9939 | Val Loss: 0.2517, Val Acc: 0.9195
# No improvement (1/7)
# Epoch 17 | Train Loss: 0.0166, Train Acc: 0.9963 | Val Loss: 0.2977, Val Acc: 0.9253
# No improvement (2/7)
# Epoch 18 | Train Loss: 0.0128, Train Acc: 0.9963 | Val Loss: 0.2842, Val Acc: 0.9253
# No improvement (3/7)
# Epoch 19 | Train Loss: 0.0109, Train Acc: 0.9975 | Val Loss: 0.2551, Val Acc: 0.9368
# No improvement (4/7)
# Epoch 20 | Train Loss: 0.0080, Train Acc: 0.9975 | Val Loss: 0.2699, Val Acc: 0.9310
# No improvement (5/7)
# Epoch 21 | Train Loss: 0.0073, Train Acc: 0.9975 | Val Loss: 0.2632, Val Acc: 0.9253
# No improvement (6/7)
# Epoch 22 | Train Loss: 0.0089, Train Acc: 0.9975 | Val Loss: 0.2763, Val Acc: 0.9310
# No improvement (7/7)
# Early stopping triggered!
