# %%
import torch
from train import *
from dataset import build_dataloaders
from bilstm import BiLSTMAttentionClassifier

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BiLSTMAttentionClassifier(
    pc_vocab=9,
    acc_vocab=10,
    oct_vocab=7,
    dur_vocab=46,
    meas_vocab=4,
    emb_dim=128,
    lstm_hidden=64,
    num_classes=12,
    dropout=0.3
)
model.to(device)

train_loader, class_weights, val_loader, _ = build_dataloaders(
    "vocab.pkl", "dataset.pkl", batch_size=8)

criterion = torch.nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=3
)

# %%
train_model(model, train_loader, val_loader, optimizer, scheduler,
            criterion, device, num_epochs=50, patience=7)
# Out:
# Epoch 01 | Train Loss: 2.0614, Train Acc: 0.3489 | Val Loss: 1.1401, Val Acc: 0.7069
# Best model saved (val_loss=1.1401)
# Epoch 02 | Train Loss: 0.7924, Train Acc: 0.7752 | Val Loss: 0.5026, Val Acc: 0.8333
# Best model saved (val_loss=0.5026)
# Epoch 03 | Train Loss: 0.5068, Train Acc: 0.8329 | Val Loss: 0.4400, Val Acc: 0.8391
# Best model saved (val_loss=0.4400)
# Epoch 04 | Train Loss: 0.3762, Train Acc: 0.8894 | Val Loss: 0.3033, Val Acc: 0.9253
# Best model saved (val_loss=0.3033)
# Epoch 05 | Train Loss: 0.2783, Train Acc: 0.9177 | Val Loss: 0.2844, Val Acc: 0.8966
# Best model saved (val_loss=0.2844)
# Epoch 06 | Train Loss: 0.2264, Train Acc: 0.9423 | Val Loss: 0.3383, Val Acc: 0.8908
# No improvement (1/7)
# Epoch 07 | Train Loss: 0.2125, Train Acc: 0.9398 | Val Loss: 0.2394, Val Acc: 0.9138
# Best model saved (val_loss=0.2394)
# Epoch 08 | Train Loss: 0.1915, Train Acc: 0.9447 | Val Loss: 0.3164, Val Acc: 0.8851
# No improvement (1/7)
# Epoch 09 | Train Loss: 0.1994, Train Acc: 0.9324 | Val Loss: 0.2494, Val Acc: 0.9195
# No improvement (2/7)
# Epoch 10 | Train Loss: 0.1535, Train Acc: 0.9595 | Val Loss: 0.2180, Val Acc: 0.9310
# Best model saved (val_loss=0.2180)
# Epoch 11 | Train Loss: 0.1193, Train Acc: 0.9668 | Val Loss: 0.2139, Val Acc: 0.9138
# Best model saved (val_loss=0.2139)
# Epoch 12 | Train Loss: 0.1416, Train Acc: 0.9484 | Val Loss: 0.2529, Val Acc: 0.9080
# No improvement (1/7)
# Epoch 13 | Train Loss: 0.1330, Train Acc: 0.9631 | Val Loss: 0.2465, Val Acc: 0.8851
# No improvement (2/7)
# Epoch 14 | Train Loss: 0.1119, Train Acc: 0.9607 | Val Loss: 0.2636, Val Acc: 0.9023
# No improvement (3/7)
# Epoch 15 | Train Loss: 0.0806, Train Acc: 0.9779 | Val Loss: 0.2185, Val Acc: 0.9138
# No improvement (4/7)
# Epoch 16 | Train Loss: 0.0547, Train Acc: 0.9889 | Val Loss: 0.2174, Val Acc: 0.9195
# No improvement (5/7)
# Epoch 17 | Train Loss: 0.0533, Train Acc: 0.9889 | Val Loss: 0.1963, Val Acc: 0.9253
# Best model saved (val_loss=0.1963)
# Epoch 18 | Train Loss: 0.0425, Train Acc: 0.9902 | Val Loss: 0.1984, Val Acc: 0.9195
# No improvement (1/7)
# Epoch 19 | Train Loss: 0.0427, Train Acc: 0.9902 | Val Loss: 0.2084, Val Acc: 0.9195
# No improvement (2/7)
# Epoch 20 | Train Loss: 0.0343, Train Acc: 0.9926 | Val Loss: 0.2182, Val Acc: 0.9253
# No improvement (3/7)
# Epoch 21 | Train Loss: 0.0299, Train Acc: 0.9951 | Val Loss: 0.1969, Val Acc: 0.9195
# No improvement (4/7)
# Epoch 22 | Train Loss: 0.0325, Train Acc: 0.9939 | Val Loss: 0.2010, Val Acc: 0.9253
# No improvement (5/7)
# Epoch 23 | Train Loss: 0.0251, Train Acc: 0.9963 | Val Loss: 0.2088, Val Acc: 0.9253
# No improvement (6/7)
# Epoch 24 | Train Loss: 0.0206, Train Acc: 0.9963 | Val Loss: 0.2011, Val Acc: 0.9253
# No improvement (7/7)
# Early stopping triggered!
